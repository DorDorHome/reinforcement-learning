# %%
# %matplotlib inline

import gymnasium as gym
import itertools
import matplotlib
import numpy as np
import pandas as pd
import sys


if "../" not in sys.path:
  sys.path.append("../") 


from lib import plotting
# Out:
# /Users/shufaichan/anaconda3/envs/RL_with_gymnasium/lib/python3.12/site-packages/gymnasium/envs/registration.py:498: UserWarning: WARN: Overriding environment GymV26Environment-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %% [markdown]
# # comparing the performance of different algorithms on :

# %%
from lib.envs.cliff_walking import CliffWalkingEnv
from lib.envs.windy_gridworld import WindyGridworldEnv
from Dyna_planning.tabular_dyna_q import random_sample_one_step_Q_planning, tabular_Dyna_Q

windy_env = WindyGridworldEnv()
clif_env = CliffWalkingEnv()

# %%
Q_dyna, stats, model = tabular_Dyna_Q(windy_env, num_real_episode = 30, num_loop_in_between_real = 50, alpha = 0.5, discount_factor = 1.0, epsilon = 0.1)

# %%
plotting.plot_episode_stats(stats)
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>)

# %%
# comparison to using SARSA:

from TD.SARSA import make_epsilon_greedy_policy
from TD.SARSA import sarsa

# %%
Q_sarsa_200, stats_sarsa_200 = sarsa(windy_env, 30)
# Out:
# Episode 30/30.

# %%
plotting.plot_episode_stats(stats_sarsa_200)
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>)

# %%
from n_step_bootstrapping.n_step_sarsa import n_step_sarsa

# %%
Q_n_sarsa_200, stats_n_sarsa_200 = n_step_sarsa(windy_env, 30, n = 10)
# Out:
# Episode 30/30.

# %%
from lib import plots
# %matplotlib inline
plots.plot_episode_stats(stats_n_sarsa_200)
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>)

# %% [markdown]
# # solve windygrid with n-step vs sarsa:
